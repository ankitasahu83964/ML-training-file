# %%
import seaborn as sns
import pandas as pd

# %%
df=sns.load_dataset('tips')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# all the features have complete values tip ans size have similar avg value

# %%
#null vaalue count in each column
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
#duplicate row count inside the data
df.duplicated().value_counts()
# Out:
# False    243
# True       1
# Name: count, dtype: int64

# %%
df[df.duplicated()]
# Out:
#      total_bill  tip     sex smoker   day   time  size
# 202        13.0  2.0  Female    Yes  Thur  Lunch     2

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().value_counts()
# Out:
# False    243
# Name: count, dtype: int64

# %%
df['total_bill'].describe()
# Out:
# count    243.000000
# mean      19.813868
# std        8.910071
# min        3.070000
# 25%       13.380000
# 50%       17.810000
# 75%       24.175000
# max       50.810000
# Name: total_bill, dtype: float64

# %%
sns.histplot(df['total_bill'],bins=20)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.boxplot(df['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
q1=df['total_bill'].describe()['25%']
q2=df['total_bill'].describe()['75%']
print(q2-q1)
v1=q2+(q2-q1)*1.5
print(v1)
# Out:
# 10.794999999999998
# 40.36749999999999

# %%
df[df['total_bill']>v1]
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4

# %%
sns.kdeplot(df['size'])
# Out:
# <Axes: xlabel='size', ylabel='Density'>

# %%
df['total_bill'].describe()
# Out:
# count    243.000000
# mean      19.813868
# std        8.910071
# min        3.070000
# 25%       13.380000
# 50%       17.810000
# 75%       24.175000
# max       50.810000
# Name: total_bill, dtype: float64

# %%
df['size'].skew()
# Out:
# np.float64(1.4416130874376414)

# %%
df['total_bill'].skew()
# Out:
# np.float64(1.1273625781584489)
