# %%
#create dataframe using dataset
import pandas as pd 
data = {
    "Name": ["A", "B", "c"],
    "Age": [10,20,30] 
    }
df = pd.DataFrame(data)
print(df)
# Out:
#   Name  Age
# 0    A   10
# 1    B   20
# 2    c   30
