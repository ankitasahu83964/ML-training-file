# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('tips')

# %%
df.sample(3)
# Out:
#      total_bill  tip   sex smoker  day    time  size
# 36        16.31  2.0  Male     No  Sat  Dinner     3
# 231       15.69  3.0  Male    Yes  Sat  Dinner     3
# 234       15.53  3.0  Male    Yes  Sat  Dinner     2

# %%
sns.scatterplot(data=df,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df,x='total_bill',y='tip',hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df,x='total_bill',y='tip',style='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df,x='total_bill',y='tip',style='time',hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df,x='total_bill',y='tip',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df,x='total_bill',y='tip', hue='sex',style='time',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot( kind='scatter',data=df,x='total_bill',y='tip', hue='sex',style='time',size='size')

# %%
! pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: plotly in C:\Users\ankit\AppData\Roaming\Python\Python314\site-packages (6.7.0)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\ankit\AppData\Roaming\Python\Python314\site-packages (from plotly) (2.19.0)
# Requirement already satisfied: packaging in C:\Users\ankit\AppData\Roaming\Python\Python314\site-packages (from plotly) (26.0)

# %%
import plotly.express as px

# %%
df1=px.data.gapminder()

# %%
df1
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# 3           4
# 4           4
# ...       ...
# 1699      716
# 1700      716
# 1701      716
# 1702      716
# 1703      716
#
# [1704 rows x 8 columns]

# %%
I_df=df1[df1['country']=='India']
I_df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 I_df=df1[df1['country']=='India']
# ----> 2 I_df1
#
# NameError: name 'I_df1' is not defined

# %%
sns.lineplot(data=I_df,x='year',y='lifeExp')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
sns.relplot( kind='scatter',data=df,x='total_bill',y='tip', col='sex')

# %%
sns.relplot( kind='scatter',data=df,x='total_bill',y='tip', row='sex')

# %%
sns.relplot( kind='scatter',data=df,x='total_bill',y='tip', col='sex',row='smoker')

# %%
sns.relplot( kind='scatter',data=df1,x='lifeExp',y='gdpPercap', col='year',col_wrap=2)
