# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("Walmart.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   str
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), str(1)
# memory usage: 402.3 KB

# %%
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    6435
# Name: count, dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Store, Date, Weekly_Sales, Holiday_Flag, Temperature, Fuel_Price, CPI, Unemployment]
# Index: []

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().value_counts()
# Out:
# False    6435
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   str
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), str(1)
# memory usage: 402.3 KB

# %%
df['CPI'].describe()
# Out:
# count    6435.000000
# mean      171.578394
# std        39.356712
# min       126.064000
# 25%       131.735000
# 50%       182.616521
# 75%       212.743293
# max       227.232807
# Name: CPI, dtype: float64

# %%
sns.histplot(df['CPI'],bins=20)
# Out:
# <Axes: xlabel='CPI', ylabel='Count'>

# %%
sns.boxplot(df['CPI'])
# Out:
# <Axes: ylabel='CPI'>

# %%
df[df['CPI'] > 40]
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
sns.kdeplot(df['CPI'])
# Out:
# <Axes: xlabel='CPI', ylabel='Density'>

# %%
df['CPI'].skew()
# Out:
# np.float64(0.06349184988549494)

# %%
df['Store'].describe()
# Out:
# count    6435.000000
# mean       23.000000
# std        12.988182
# min         1.000000
# 25%        12.000000
# 50%        23.000000
# 75%        34.000000
# max        45.000000
# Name: Store, dtype: float64

# %%
sns.histplot(df['Store'])
# Out:
# <Axes: xlabel='Store', ylabel='Count'>

# %%
sns.boxplot(df['Store'])
# Out:
# <Axes: ylabel='Store'>

# %%
df[df['Store'] > 4]
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 572       5  05-02-2010     317173.10             0        39.70       2.572
# 573       5  12-02-2010     311825.70             1        39.81       2.548
# 574       5  19-02-2010     303447.57             0        41.14       2.514
# 575       5  26-02-2010     270281.63             0        46.70       2.561
# 576       5  05-03-2010     288855.71             0        48.89       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
sns.kdeplot(df['Store'])
# Out:
# <Axes: xlabel='Store', ylabel='Density'>

# %%
df['Store'].skew()
# Out:
# np.float64(0.0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   str
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), str(1)
# memory usage: 402.3 KB

# %%
df['Weekly_Sales'].value_counts()
# Out:
# Weekly_Sales
# 1643690.90    1
# 1641957.44    1
# 1611968.17    1
# 1409727.59    1
# 1554806.68    1
#              ..
# 713173.95     1
# 733455.07     1
# 734464.36     1
# 718125.53     1
# 760281.43     1
# Name: count, Length: 6435, dtype: int64

# %%
sns.barplot(df['Weekly_Sales'].value_counts())
# Out:
# <Axes: xlabel='Weekly_Sales', ylabel='count'>

# %%
df['Holiday_Flag'].value_counts().plot(kind='pie',autopct='%0.00f%%')f['
# Out:
# <Axes: >

# %%
df['Holiday_Flag'].value_counts()
# Out:
# Holiday_Flag
# 0    5985
# 1     450
# Name: count, dtype: int64

# %%
df['Store'].value_counts().plot(kind='pie',autopct='%0.01f%%')
# Out:
# <Axes: >

# %%
df['Temperature'].value_counts()
# Out:
# Temperature
# 50.43    11
# 67.87    10
# 72.62     9
# 76.67     9
# 70.28     9
#          ..
# 82.01     1
# 86.36     1
# 75.87     1
# 77.55     1
# 74.09     1
# Name: count, Length: 3528, dtype: int64

# %%
sns.barplot(df['Weekly_Sales'].value_counts())
# Out:
# <Axes: xlabel='Weekly_Sales', ylabel='count'>

# %%
df[['Date','Store']].describe()
# Out:
#              Store
# count  6435.000000
# mean     23.000000
# std      12.988182
# min       1.000000
# 25%      12.000000
# 50%      23.000000
# 75%      34.000000
# max      45.000000

# %%
sns.scatterplot(data=df, x='Weekly_Sales',y='Store')
# Out:
# <Axes: xlabel='Weekly_Sales', ylabel='Store'>
